# %% [markdown]
# 5 NUMBER SUMMARY USING PYTHON (Boxplot)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("loan_data.csv")
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
Credit_Score = df["credit_score"].values
Credit_Score
# Out:
# array([561, 504, 635, ..., 668, 604, 628], dtype=int64)

# %%
Credit_Score_array = np.sort(Credit_Score)

# Calculate Statistics
minimum = np.min(Credit_Score_array) # Smallest value
q1 = np.percentile(Credit_Score_array, 25) # The value below 25%
median = np.median(Credit_Score_array) # Middle value
q3 = np.percentile(Credit_Score_array, 75) # The value upper half of median and falls below 75%
maximum = np.max(Credit_Score_array)

print(f"Minimum ={minimum}")
print(f"Q1 ={q1}")
print(f"Median ={median} ")
print(f"Q3 ={q3}")
print(f"Maximum ={maximum}")

# Plotting the boxplot
plt.boxplot(Price_Today_array,vert=False)
plt.title('Box plot of Credit Score Values')
plt.ylabel('Credit Score')
plt.show()
# Out:
# Minimum =390
# Q1 =601.0
# Median =640.0
# Q3 =670.0
# Maximum =850
