# %% [markdown]
# 6.  Perform Decision Tree classification algorithm on given data set.

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# Convering datatype object into binary of clumn 'Nationality' and 'GO' such as, 'UK':0, 'USA':1 and 'N':1
d = {'male': 0, 'female': 1}
df['Sex'] = df['Sex'].map(d)
d = {'Q': 0, 'S': 1, 'C': 2}
df['Embarked'] = df['Embarked'].map(d)

print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    0  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                                Wirz, Mr. Albert    0  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    0   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina    1  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    0  38.5      0      0
# 416                           Ware, Mr. Frederick    0   NaN      0      0
# 417                      Peter, Master. Michael J    0   NaN      1      1
#
#                  Ticket      Fare Cabin  Embarked
# 0                330911    7.8292   NaN         0
# 1                363272    7.0000   NaN         1
# 2                240276    9.6875   NaN         0
# 3                315154    8.6625   NaN         1
# 4               3101298   12.2875   NaN         1
# ..                  ...       ...   ...       ...
# 413           A.5. 3236    8.0500   NaN         1
# 414            PC 17758  108.9000  C105         2
# 415  SOTON/O.Q. 3101262    7.2500   NaN         1
# 416              359309    8.0500   NaN         1
# 417                2668   22.3583   NaN         2
#
# [418 rows x 12 columns]

# %%
# Feature Selection
features = ['Age', 'Survived', 'SibSp']

X = df[features]
y = df['Embarked']

print(X)
print(y)
# Out:
#       Age  Survived  SibSp
# 0    34.5         0      0
# 1    47.0         1      1
# 2    62.0         0      0
# 3    27.0         0      0
# 4    22.0         1      1
# ..    ...       ...    ...
# 413   NaN         0      0
# 414  39.0         1      0
# 415  38.5         0      0
# 416   NaN         0      0
# 417   NaN         0      1
#
# [418 rows x 3 columns]
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 413    1
# 414    2
# 415    1
# 416    1
# 417    2
# Name: Embarked, Length: 418, dtype: int64

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.5841292134831461, 0.96875, 'Age <= 34.25\ngini = 0.511\nsamples = 418\nvalue = [46, 270, 102]'),
#  Text(0.41685393258426967, 0.90625, 'Age <= inf\ngini = 0.404\nsamples = 221\nvalue = [15.0, 165.0, 41.0]'),
#  Text(0.5004915730337078, 0.9375, 'True  '),
#  Text(0.40786516853932586, 0.84375, 'SibSp <= 1.5\ngini = 0.4\nsamples = 220\nvalue = [15.0, 165.0, 40.0]'),
#  Text(0.2943820224719101, 0.78125, 'SibSp <= 0.5\ngini = 0.414\nsamples = 202\nvalue = [14.0, 149.0, 39.0]'),
#  Text(0.18764044943820224, 0.71875, 'Survived <= 0.5\ngini = 0.41\nsamples = 149\nvalue = [14, 111, 24]'),
#  Text(0.06292134831460675, 0.65625, 'Age <= 18.25\ngini = 0.361\nsamples = 104\nvalue = [5, 81, 18]'),
#  Text(0.02696629213483146, 0.59375, 'Age <= 7.0\ngini = 0.117\nsamples = 16\nvalue = [0, 15, 1]'),
#  Text(0.017977528089887642, 0.53125, 'Age <= 3.415\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.008988764044943821, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.02696629213483146, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.035955056179775284, 0.53125, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(0.09887640449438202, 0.59375, 'Age <= 22.75\ngini = 0.397\nsamples = 88\nvalue = [5, 66, 17]'),
#  Text(0.05393258426966292, 0.53125, 'Age <= 22.25\ngini = 0.517\nsamples = 24\nvalue = [2, 15, 7]'),
#  Text(0.0449438202247191, 0.46875, 'Age <= 20.5\ngini = 0.499\nsamples = 23\nvalue = [2, 15, 6]'),
#  Text(0.02696629213483146, 0.40625, 'Age <= 19.5\ngini = 0.49\nsamples = 7\nvalue = [0, 4, 3]'),
#  Text(0.017977528089887642, 0.34375, 'Age <= 18.75\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.008988764044943821, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.02696629213483146, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.035955056179775284, 0.34375, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.06292134831460675, 0.40625, 'Age <= 21.5\ngini = 0.477\nsamples = 16\nvalue = [2, 11, 3]'),
#  Text(0.05393258426966292, 0.34375, 'gini = 0.529\nsamples = 11\nvalue = [2, 7, 2]'),
#  Text(0.07191011235955057, 0.34375, 'gini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.06292134831460675, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.14382022471910114, 0.53125, 'Age <= 26.25\ngini = 0.338\nsamples = 64\nvalue = [3, 51, 10]'),
#  Text(0.11685393258426967, 0.46875, 'Age <= 24.5\ngini = 0.24\nsamples = 30\nvalue = [2, 26, 2]'),
#  Text(0.09887640449438202, 0.40625, 'Age <= 23.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12, 0]'),
#  Text(0.0898876404494382, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.10786516853932585, 0.34375, 'gini = 0.198\nsamples = 9\nvalue = [1, 8, 0]'),
#  Text(0.1348314606741573, 0.40625, 'Age <= 25.5\ngini = 0.304\nsamples = 17\nvalue = [1, 14, 2]'),
#  Text(0.1258426966292135, 0.34375, 'gini = 0.32\nsamples = 10\nvalue = [0, 8, 2]'),
#  Text(0.14382022471910114, 0.34375, 'gini = 0.245\nsamples = 7\nvalue = [1, 6, 0]'),
#  Text(0.1707865168539326, 0.46875, 'Age <= 26.75\ngini = 0.403\nsamples = 34\nvalue = [1, 25, 8]'),
#  Text(0.16179775280898875, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.1797752808988764, 0.40625, 'Age <= 31.5\ngini = 0.38\nsamples = 33\nvalue = [1, 25, 7]'),
#  Text(0.16179775280898875, 0.34375, 'Age <= 30.5\ngini = 0.459\nsamples = 22\nvalue = [1.0, 15.0, 6.0]'),
#  Text(0.15280898876404495, 0.28125, 'Age <= 28.25\ngini = 0.375\nsamples = 20\nvalue = [0, 15, 5]'),
#  Text(0.1348314606741573, 0.21875, 'Age <= 27.5\ngini = 0.298\nsamples = 11\nvalue = [0, 9, 2]'),
#  Text(0.1258426966292135, 0.15625, 'gini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.14382022471910114, 0.15625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.1707865168539326, 0.21875, 'Age <= 28.75\ngini = 0.444\nsamples = 9\nvalue = [0, 6, 3]'),
#  Text(0.16179775280898875, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.1797752808988764, 0.15625, 'Age <= 29.5\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 2]'),
#  Text(0.1707865168539326, 0.09375, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.18876404494382024, 0.09375, 'gini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.1707865168539326, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.19775280898876405, 0.34375, 'Age <= 32.25\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.18876404494382024, 0.28125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.20674157303370785, 0.28125, 'Age <= 32.75\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.19775280898876405, 0.21875, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.2157303370786517, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.31235955056179776, 0.65625, 'Age <= 30.5\ngini = 0.498\nsamples = 45\nvalue = [9, 30, 6]'),
#  Text(0.28314606741573034, 0.59375, 'Age <= 23.5\ngini = 0.484\nsamples = 40\nvalue = [9, 27, 4]'),
#  Text(0.251685393258427, 0.53125, 'Age <= 18.75\ngini = 0.461\nsamples = 27\nvalue = [4, 19, 4]'),
#  Text(0.23370786516853934, 0.46875, 'Age <= 16.5\ngini = 0.54\nsamples = 10\nvalue = [3, 6, 1]'),
#  Text(0.2247191011235955, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.24269662921348314, 0.40625, 'Age <= 18.25\ngini = 0.612\nsamples = 7\nvalue = [3, 3, 1]'),
#  Text(0.23370786516853934, 0.34375, 'Age <= 17.5\ngini = 0.611\nsamples = 6\nvalue = [2, 3, 1]'),
#  Text(0.2247191011235955, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.24269662921348314, 0.28125, 'gini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.251685393258427, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.2696629213483146, 0.46875, 'Age <= 21.5\ngini = 0.381\nsamples = 17\nvalue = [1, 13, 3]'),
#  Text(0.2606741573033708, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.2786516853932584, 0.40625, 'Age <= 22.5\ngini = 0.512\nsamples = 11\nvalue = [1, 7, 3]'),
#  Text(0.2696629213483146, 0.34375, 'gini = 0.571\nsamples = 7\nvalue = [1, 4, 2]'),
#  Text(0.2876404494382023, 0.34375, 'gini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.3146067415730337, 0.53125, 'Age <= 25.0\ngini = 0.473\nsamples = 13\nvalue = [5, 8, 0]'),
#  Text(0.3056179775280899, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.3235955056179775, 0.46875, 'Age <= 29.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8, 0]'),
#  Text(0.3146067415730337, 0.40625, 'Age <= 27.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0]'),
#  Text(0.3056179775280899, 0.34375, 'Age <= 26.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.2966292134831461, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.3146067415730337, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3235955056179775, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.3325842696629214, 0.40625, 'gini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.3415730337078652, 0.59375, 'Age <= 32.0\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.3325842696629214, 0.53125, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.350561797752809, 0.53125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.401123595505618, 0.71875, 'Age <= 4.5\ngini = 0.406\nsamples = 53\nvalue = [0, 38, 15]'),
#  Text(0.3685393258426966, 0.65625, 'Age <= 0.96\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1]'),
#  Text(0.3595505617977528, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.3775280898876405, 0.59375, 'Age <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.3685393258426966, 0.53125, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.3865168539325843, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.4337078651685393, 0.65625, 'Age <= 7.5\ngini = 0.434\nsamples = 44\nvalue = [0.0, 30.0, 14.0]'),
#  Text(0.4247191011235955, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.44269662921348313, 0.59375, 'Survived <= 0.5\ngini = 0.408\nsamples = 42\nvalue = [0, 30, 12]'),
#  Text(0.4044943820224719, 0.53125, 'Age <= 19.5\ngini = 0.291\nsamples = 17\nvalue = [0, 14, 3]'),
#  Text(0.3865168539325843, 0.46875, 'Age <= 14.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.3775280898876405, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3955056179775281, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.42247191011235957, 0.46875, 'Age <= 26.5\ngini = 0.231\nsamples = 15\nvalue = [0, 13, 2]'),
#  Text(0.4134831460674157, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.4314606741573034, 0.40625, 'Age <= 28.0\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 2]'),
#  Text(0.42247191011235957, 0.34375, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4404494382022472, 0.34375, 'Age <= 29.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.4314606741573034, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.449438202247191, 0.28125, 'Age <= 32.0\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.4404494382022472, 0.21875, 'gini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.4584269662921348, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.48089887640449436, 0.53125, 'Age <= 17.0\ngini = 0.461\nsamples = 25\nvalue = [0, 16, 9]'),
#  Text(0.4584269662921348, 0.46875, 'Age <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.449438202247191, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.46741573033707867, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.503370786516854, 0.46875, 'Age <= 23.5\ngini = 0.434\nsamples = 22\nvalue = [0.0, 15.0, 7.0]'),
#  Text(0.4853932584269663, 0.40625, 'Age <= 19.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1]'),
#  Text(0.4764044943820225, 0.34375, 'Age <= 18.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.46741573033707867, 0.28125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.4853932584269663, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4943820224719101, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.5213483146067416, 0.40625, 'Age <= 25.5\ngini = 0.497\nsamples = 13\nvalue = [0, 7, 6]'),
#  Text(0.5123595505617977, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5303370786516854, 0.34375, 'Age <= 28.0\ngini = 0.42\nsamples = 10\nvalue = [0, 7, 3]'),
#  Text(0.5123595505617977, 0.28125, 'Age <= 26.5\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.503370786516854, 0.21875, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5213483146067416, 0.21875, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5483146067415731, 0.28125, 'Age <= 29.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.5393258426966292, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.5573033707865168, 0.21875, 'Age <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5483146067415731, 0.15625, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5662921348314607, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5213483146067416, 0.78125, 'Age <= 13.75\ngini = 0.204\nsamples = 18\nvalue = [1, 16, 1]'),
#  Text(0.5123595505617977, 0.71875, 'SibSp <= 2.5\ngini = 0.449\nsamples = 7\nvalue = [1, 5, 1]'),
#  Text(0.4943820224719101, 0.65625, 'Age <= 12.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4853932584269663, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.503370786516854, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5303370786516854, 0.65625, 'Age <= 8.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0]'),
#  Text(0.5213483146067416, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.5393258426966292, 0.59375, 'Age <= 11.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.5303370786516854, 0.53125, 'SibSp <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.5213483146067416, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5393258426966292, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5483146067415731, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5303370786516854, 0.71875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0]'),
#  Text(0.4258426966292135, 0.84375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7514044943820225, 0.90625, 'Age <= 35.5\ngini = 0.595\nsamples = 197\nvalue = [31.0, 105.0, 61.0]'),
#  Text(0.6677668539325843, 0.9375, '  False'),
#  Text(0.6292134831460674, 0.84375, 'Age <= 29.25\ngini = 0.634\nsamples = 92\nvalue = [26.0, 44.0, 22.0]'),
#  Text(0.5932584269662922, 0.78125, 'Survived <= 0.5\ngini = 0.621\nsamples = 85\nvalue = [23, 43, 19]'),
#  Text(0.5752808988764045, 0.71875, 'SibSp <= 1.5\ngini = 0.604\nsamples = 60\nvalue = [12, 32, 16]'),
#  Text(0.5662921348314607, 0.65625, 'SibSp <= 0.5\ngini = 0.595\nsamples = 58\nvalue = [12, 32, 14]'),
#  Text(0.5573033707865168, 0.59375, 'gini = 0.581\nsamples = 49\nvalue = [11, 28, 10]'),
#  Text(0.5752808988764045, 0.59375, 'gini = 0.593\nsamples = 9\nvalue = [1, 4, 4]'),
#  Text(0.5842696629213483, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6112359550561798, 0.71875, 'SibSp <= 5.0\ngini = 0.598\nsamples = 25\nvalue = [11, 11, 3]'),
#  Text(0.6022471910112359, 0.65625, 'SibSp <= 1.5\ngini = 0.601\nsamples = 24\nvalue = [11, 10, 3]'),
#  Text(0.5932584269662922, 0.59375, 'SibSp <= 0.5\ngini = 0.605\nsamples = 23\nvalue = [10, 10, 3]'),
#  Text(0.5842696629213483, 0.53125, 'gini = 0.586\nsamples = 18\nvalue = [9, 7, 2]'),
#  Text(0.6022471910112359, 0.53125, 'gini = 0.56\nsamples = 5\nvalue = [1, 3, 1]'),
#  Text(0.6112359550561798, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6202247191011236, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6651685393258427, 0.78125, 'Survived <= 0.5\ngini = 0.612\nsamples = 7\nvalue = [3, 1, 3]'),
#  Text(0.647191011235955, 0.71875, 'Age <= 34.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.6382022471910113, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6561797752808989, 0.65625, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.6831460674157304, 0.71875, 'Age <= 44.0\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.6741573033707865, 0.65625, 'SibSp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2]'),
#  Text(0.6651685393258427, 0.59375, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.6831460674157304, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6921348314606741, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8735955056179775, 0.84375, 'Age <= inf\ngini = 0.522\nsamples = 105\nvalue = [5.0, 61.0, 39.0]'),
#  Text(0.8646067415730337, 0.78125, 'SibSp <= 1.5\ngini = 0.514\nsamples = 104\nvalue = [4, 61, 39]'),
#  Text(0.8556179775280899, 0.71875, 'Survived <= 0.5\ngini = 0.52\nsamples = 101\nvalue = [4.0, 58.0, 39.0]'),
#  Text(0.7606741573033707, 0.65625, 'Age <= 60.75\ngini = 0.481\nsamples = 64\nvalue = [2, 41, 21]'),
#  Text(0.701123595505618, 0.59375, 'Age <= 39.5\ngini = 0.441\nsamples = 58\nvalue = [0, 39, 19]'),
#  Text(0.6674157303370787, 0.53125, 'Age <= 38.75\ngini = 0.5\nsamples = 12\nvalue = [0, 6, 6]'),
#  Text(0.6584269662921348, 0.46875, 'Age <= 37.5\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 2]'),
#  Text(0.6494382022471911, 0.40625, 'Age <= 36.75\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.6404494382022472, 0.34375, 'SibSp <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.6314606741573033, 0.28125, 'gini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.6494382022471911, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6584269662921348, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6674157303370787, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6764044943820224, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.7348314606741573, 0.53125, 'Age <= 42.5\ngini = 0.405\nsamples = 46\nvalue = [0.0, 33.0, 13.0]'),
#  Text(0.6943820224719102, 0.46875, 'Age <= 40.75\ngini = 0.117\nsamples = 16\nvalue = [0, 15, 1]'),
#  Text(0.6853932584269663, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.7033707865168539, 0.40625, 'Age <= 41.5\ngini = 0.18\nsamples = 10\nvalue = [0, 9, 1]'),
#  Text(0.6943820224719102, 0.34375, 'SibSp <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.6853932584269663, 0.28125, 'gini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.7033707865168539, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7123595505617978, 0.34375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.7752808988764045, 0.46875, 'SibSp <= 0.5\ngini = 0.48\nsamples = 30\nvalue = [0, 18, 12]'),
#  Text(0.7393258426966293, 0.40625, 'Age <= 44.5\ngini = 0.415\nsamples = 17\nvalue = [0, 12, 5]'),
#  Text(0.7303370786516854, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.748314606741573, 0.34375, 'Age <= 46.5\ngini = 0.459\nsamples = 14\nvalue = [0, 9, 5]'),
#  Text(0.7303370786516854, 0.28125, 'Age <= 45.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.7213483146067415, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7393258426966293, 0.21875, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.7662921348314606, 0.28125, 'Age <= 54.0\ngini = 0.32\nsamples = 10\nvalue = [0, 8, 2]'),
#  Text(0.7573033707865169, 0.21875, 'Age <= 51.5\ngini = 0.408\nsamples = 7\nvalue = [0, 5, 2]'),
#  Text(0.748314606741573, 0.15625, 'Age <= 48.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.7393258426966293, 0.09375, 'Age <= 47.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.7303370786516854, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.748314606741573, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7573033707865169, 0.09375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.7662921348314606, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7752808988764045, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.8112359550561797, 0.40625, 'Age <= 48.0\ngini = 0.497\nsamples = 13\nvalue = [0, 6, 7]'),
#  Text(0.802247191011236, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8202247191011236, 0.34375, 'Age <= 53.5\ngini = 0.48\nsamples = 10\nvalue = [0, 6, 4]'),
#  Text(0.802247191011236, 0.28125, 'Age <= 49.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.7932584269662921, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8112359550561797, 0.21875, 'Age <= 51.5\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.802247191011236, 0.15625, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.8202247191011236, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8382022471910112, 0.28125, 'Age <= 54.5\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.8292134831460675, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8471910112359551, 0.21875, 'Age <= 56.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.8382022471910112, 0.15625, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8561797752808988, 0.15625, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8202247191011236, 0.59375, 'SibSp <= 0.5\ngini = 0.667\nsamples = 6\nvalue = [2, 2, 2]'),
#  Text(0.8112359550561797, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8292134831460675, 0.53125, 'Age <= 62.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.8202247191011236, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8382022471910112, 0.46875, 'Age <= 63.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.8292134831460675, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8471910112359551, 0.40625, 'Age <= 65.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8382022471910112, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8561797752808988, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.950561797752809, 0.65625, 'SibSp <= 0.5\ngini = 0.549\nsamples = 37\nvalue = [2, 17, 18]'),
#  Text(0.9191011235955057, 0.59375, 'Age <= 53.0\ngini = 0.503\nsamples = 21\nvalue = [1, 7, 13]'),
#  Text(0.9101123595505618, 0.53125, 'Age <= 46.5\ngini = 0.555\nsamples = 16\nvalue = [1, 7, 8]'),
#  Text(0.9011235955056179, 0.46875, 'Age <= 37.5\ngini = 0.541\nsamples = 14\nvalue = [1, 5, 8]'),
#  Text(0.8831460674157303, 0.40625, 'Age <= 36.5\ngini = 0.611\nsamples = 6\nvalue = [1, 3, 2]'),
#  Text(0.8741573033707866, 0.34375, 'gini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.8921348314606742, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9191011235955057, 0.40625, 'Age <= 38.5\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6]'),
#  Text(0.9101123595505618, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9280898876404494, 0.34375, 'Age <= 42.0\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5]'),
#  Text(0.9191011235955057, 0.28125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.9370786516853933, 0.28125, 'gini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.9191011235955057, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.9280898876404494, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.9820224719101124, 0.59375, 'Age <= 52.0\ngini = 0.508\nsamples = 16\nvalue = [1, 10, 5]'),
#  Text(0.9730337078651685, 0.53125, 'Age <= 47.5\ngini = 0.58\nsamples = 10\nvalue = [1, 4, 5]'),
#  Text(0.9640449438202248, 0.46875, 'Age <= 44.0\ngini = 0.5\nsamples = 6\nvalue = [1, 4, 1]'),
#  Text(0.9550561797752809, 0.40625, 'Age <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.946067415730337, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9640449438202248, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9730337078651685, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.9820224719101124, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.9910112359550561, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.8735955056179775, 0.71875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.8825842696629214, 0.78125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]')]
